# %% [markdown]
# # Segmentasi Tumor Otak

# %%
import os
import cv2
import glob
import time
import joblib
import pathlib
import numpy as np
import nibabel as nib
import tensorflow as tf
import tensorflow_graphics as tfg
import tensorflow_probability as tfp
import tensorflow.keras.backend as K
from tqdm import tqdm
from keras.models import Model
from keras.metrics import MeanIoU
from matplotlib import pyplot as plt
from tensorflow.keras.utils import normalize
from IPython.display import display, Markdown
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow_graphics.nn.loss.hausdorff_distance import evaluate as hausdorff_distance_eval
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda

# %% [markdown]
# ## Pengaturan Hyperparameter dan Konfigurasi Model

# %%
# Menginisialisasi hyperparameter
INIT_LR = 1e-3
EPOCHS = 250
BS = 128
SIZE_X = 112
SIZE_Y = 112
n_classes = 4
IMG_CHANNELS = 1

NETWORK = "UNet_Tesis"

dataset = "C:/Users/Lab129/Downloads/Indi/Dataset Seg 128"
model_path = f"{NETWORK}_{SIZE_X}_{EPOCHS}_{BS}.model"
encoder_path = model_path + "_encoder.joblib"

# %% [markdown]
# ## Pre-processing Data

# %%
data_dir=pathlib.Path(dataset)

images_dir = [str(dir) for dir in data_dir.glob('*/Images/*.jpg')]
masks_dir = [str(dir) for dir in data_dir.glob('*/Masks/*.png')]
display(
    Markdown(f"**Training images**: {len(images_dir)}"),
    Markdown(f"**Mask images**: {len(masks_dir)}")
)
# Out:
# **Training images**: 47232
# **Mask images**: 47232

# %%
X_dirs, X_dirs_test, y_dirs, y_dirs_test = train_test_split(images_dir, masks_dir, test_size=0.20, random_state=42)

# %%
def image_generator(image_paths: list[str], interpolation=None):
    for index, image_path in enumerate(image_paths):
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if interpolation is not None:
            image = cv2.resize(image, (SIZE_X, SIZE_Y), interpolation=interpolation)
        else:
            image = cv2.resize(image, (SIZE_X, SIZE_Y))
        yield image

# %%
encoder = LabelEncoder()
# Periksa encoder
if os.path.exists(encoder_path):
    display(Markdown("**Loading encoder from file**"))
    encoder: LabelEncoder = joblib.load(encoder_path)
else:
    display(Markdown("**Images on encoder**"))
    batch_size=1
    generator = image_generator(y_dirs, interpolation=cv2.INTER_NEAREST)
    # Memuat progress bar saat memuat gambar
    uniques = set()
    for matrice in tqdm(generator, total=len(y_dirs), desc="Fitting images on encoder..."):
        uniques.update(np.unique(matrice.flatten()))
    encoder.fit(list(uniques))
    joblib.dump(encoder, encoder_path)
encoder.classes_
# Out:
# **Images on encoder**
# Fitting images on encoder...: 100%|███████████████████████████████████████████████████████████████████████| 37785/37785 [00:28<00:00, 1343.33it/s]
# array([  0,  64, 128, 255], dtype=uint8)

# %%
def data_generator(xdirs, ydirs):
    X_gen = image_generator(xdirs)
    y_gen = image_generator(ydirs, interpolation=cv2.INTER_NEAREST)
    while True:
        try:
            X, y = next(X_gen), next(y_gen)

            h, w = y.shape
            
            X = np.expand_dims(X, axis=2)

            X: np.ndarray = normalize(X, axis=1)

            y_res_encode: np.ndarray = encoder.transform(y.reshape(-1,1).ravel())
            y_encoded = y_res_encode.reshape(h, w)

            y_expanded = np.expand_dims(y_encoded, axis=2)

            y_cat: np.ndarray = to_categorical(y_expanded.ravel(), num_classes=n_classes)
            y_cat = y_cat.reshape((h, w, n_classes))
            yield X, y_cat
        except StopIteration:
            return

# %%
val_total_items = len(X_dirs_test)
val_num_batches = val_total_items // BS
val_dataset = tf.data.Dataset.from_generator(lambda: data_generator(X_dirs_test, y_dirs_test),
    output_types=(tf.float32, tf.float32),  # Assuming X and y are both float32
    output_shapes=((None, None, 1), (None, None, n_classes))  # Assuming the shapes of X and y
)
val_dataset = val_dataset.batch(BS)
val_dataset = val_dataset.prefetch(tf.data.AUTOTUNE)

train_total_items = len(X_dirs)
train_num_batches = train_total_items // BS
train_dataset = tf.data.Dataset.from_generator(lambda: data_generator(X_dirs, y_dirs),
    output_types=(tf.float32, tf.float32),  # Assuming X and y are both float32
    output_shapes=((None, None, 1), (None, None, n_classes))  # Assuming the shapes of X and y
)
train_dataset = train_dataset.batch(BS)
train_dataset = train_dataset.repeat(EPOCHS)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Pengembangan Model

# %%
starttime = time.time()

def multi_unet_model(n_classes=n_classes, IMG_HEIGHT=SIZE_X, IMG_WIDTH=SIZE_Y, IMG_CHANNELS=IMG_CHANNELS):
# Mengembangkan model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = inputs

    # Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    # Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def hd95_metric(y_true, y_pred):
    value = tfg.nn.loss.hausdorff_distance.evaluate(y_true, y_pred)
    percentile = tfp.stats.percentile(value, 95.0, interpolation='lower')
    return percentile

# %%
model = multi_unet_model()

print("[INFO] compiling model...")
model.compile(loss="categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR), 
              metrics = [
                  'accuracy',
                  tf.keras.metrics.MeanIoU(num_classes=n_classes),
                  dice_coef, 
                  precision,
                  sensitivity,
                  specificity,
                  hd95_metric,
              ])
# Out:
# [INFO] compiling model...

# %% [markdown]
# ## Proses Pelatihan Model

# %%
print("[INFO] training...")
history = model.fit(train_dataset,
                    batch_size=BS, 
                    verbose=1, 
                    steps_per_epoch=train_num_batches,
                    epochs=EPOCHS, 
                    validation_data=val_dataset,
                    validation_steps=val_num_batches,
                    validation_batch_size=BS,
                    shuffle=False)

endtime = time.time()

# Tampilkan running time
print("Running time: {} s".format(endtime - starttime))
# Out:
# [INFO] training...
# Epoch 1/250
250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0122 - accuracy: 0.9952 - mean_io_u: 0.8764 - dice_coef: 0.7031 - precision: 0.9961 - sensitivity: 0.9945 - specificity: 0.9987 - hd95_metric: 0.3901 - val_loss: 0.0117 - val_accuracy: 0.9954 - val_mean_io_u: 0.8619 - val_dice_coef: 0.7159 - val_precision: 0.9961 - val_sensitivity: 0.9948 - val_specificity: 0.9987 - val_hd95_metric: 0.3835
# Epoch 22/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0120 - accuracy: 0.9953 - mean_io_u: 0.8777 - dice_coef: 0.7070 - precision: 0.9961 - sensitivity: 0.9946 - specificity: 0.9987 - hd95_metric: 0.3774 - val_loss: 0.0119 - val_accuracy: 0.9953 - val_mean_io_u: 0.8492 - val_dice_coef: 0.7087 - val_precision: 0.9960 - val_sensitivity: 0.9947 - val_specificity: 0.9987 - val_hd95_metric: 0.3742
# Epoch 23/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0119 - accuracy: 0.9953 - mean_io_u: 0.8729 - dice_coef: 0.7096 - precision: 0.9961 - sensitivity: 0.9947 - specificity: 0.9987 - hd95_metric: 0.3683 - val_loss: 0.0118 - val_accuracy: 0.9954 - val_mean_io_u: 0.8617 - val_dice_coef: 0.7178 - val_precision: 0.9961 - val_sensitivity: 0.9948 - val_specificity: 0.9987 - val_hd95_metric: 0.3271
# Epoch 24/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0117 - accuracy: 0.9954 - mean_io_u: 0.8724 - dice_coef: 0.7130 - precision: 0.9962 - sensitivity: 0.9948 - specificity: 0.9987 - hd95_metric: 0.3597 - val_loss: 0.0114 - val_accuracy: 0.9956 - val_mean_io_u: 0.8515 - val_dice_coef: 0.7344 - val_precision: 0.9961 - val_sensitivity: 0.9951 - val_specificity: 0.9987 - val_hd95_metric: 0.2781
# Epoch 25/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0114 - accuracy: 0.9955 - mean_io_u: 0.8771 - dice_coef: 0.7212 - precision: 0.9962 - sensitivity: 0.9950 - specificity: 0.9987 - hd95_metric: 0.3406 - val_loss: 0.0110 - val_accuracy: 0.9957 - val_mean_io_u: 0.8670 - val_dice_coef: 0.7308 - val_precision: 0.9964 - val_sensitivity: 0.9951 - val_specificity: 0.9988 - val_hd95_metric: 0.3338
# Epoch 26/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0113 - accuracy: 0.9956 - mean_io_u: 0.8809 - dice_coef: 0.7235 - precision: 0.9963 - sensitivity: 0.9950 - specificity: 0.9988 - hd95_metric: 0.3317 - val_loss: 0.0109 - val_accuracy: 0.9957 - val_mean_io_u: 0.8589 - val_dice_coef: 0.7326 - val_precision: 0.9964 - val_sensitivity: 0.9952 - val_specificity: 0.9988 - val_hd95_metric: 0.3150
# Epoch 27/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0111 - accuracy: 0.9956 - mean_io_u: 0.8823 - dice_coef: 0.7273 - precision: 0.9963 - sensitivity: 0.9951 - specificity: 0.9988 - hd95_metric: 0.3204 - val_loss: 0.0110 - val_accuracy: 0.9956 - val_mean_io_u: 0.8823 - val_dice_coef: 0.7314 - val_precision: 0.9963 - val_sensitivity: 0.9950 - val_specificity: 0.9988 - val_hd95_metric: 0.3712
# Epoch 28/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.
250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0098 - accuracy: 0.9961 - mean_io_u: 0.8961 - dice_coef: 0.7586 - precision: 0.9966 - sensitivity: 0.9957 - specificity: 0.9989 - hd95_metric: 0.2316 - val_loss: 0.0099 - val_accuracy: 0.9962 - val_mean_io_u: 0.8768 - val_dice_coef: 0.7632 - val_precision: 0.9966 - val_sensitivity: 0.9958 - val_specificity: 0.9989 - val_hd95_metric: 0.2150
# Epoch 43/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0098 - accuracy: 0.9961 - mean_io_u: 0.8925 - dice_coef: 0.7584 - precision: 0.9966 - sensitivity: 0.9957 - specificity: 0.9989 - hd95_metric: 0.2309 - val_loss: 0.0100 - val_accuracy: 0.9962 - val_mean_io_u: 0.8971 - val_dice_coef: 0.7644 - val_precision: 0.9966 - val_sensitivity: 0.9958 - val_specificity: 0.9989 - val_hd95_metric: 0.2591
# Epoch 44/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0098 - accuracy: 0.9961 - mean_io_u: 0.8938 - dice_coef: 0.7569 - precision: 0.9966 - sensitivity: 0.9957 - specificity: 0.9989 - hd95_metric: 0.2337 - val_loss: 0.0098 - val_accuracy: 0.9962 - val_mean_io_u: 0.9103 - val_dice_coef: 0.7637 - val_precision: 0.9966 - val_sensitivity: 0.9958 - val_specificity: 0.9989 - val_hd95_metric: 0.2578
# Epoch 45/250
# 295/295 [==============================] - 243s 823ms/step - loss: 0.0097 - accuracy: 0.9962 - mean_io_u: 0.8952 - dice_coef: 0.7606 - precision: 0.9967 - sensitivity: 0.9958 - specificity: 0.9989 - hd95_metric: 0.2251 - val_loss: 0.0098 - val_accuracy: 0.9962 - val_mean_io_u: 0.8844 - val_dice_coef: 0.7673 - val_precision: 0.9967 - val_sensitivity: 0.9958 - val_specificity: 0.9989 - val_hd95_metric: 0.2260
# Epoch 46/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0097 - accuracy: 0.9962 - mean_io_u: 0.8937 - dice_coef: 0.7615 - precision: 0.9967 - sensitivity: 0.9958 - specificity: 0.9989 - hd95_metric: 0.2251 - val_loss: 0.0098 - val_accuracy: 0.9962 - val_mean_io_u: 0.8715 - val_dice_coef: 0.7666 - val_precision: 0.9967 - val_sensitivity: 0.9958 - val_specificity: 0.9989 - val_hd95_metric: 0.2153
# Epoch 47/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0096 - accuracy: 0.9962 - mean_io_u: 0.8949 - dice_coef: 0.7627 - precision: 0.9967 - sensitivity: 0.9958 - specificity: 0.9989 - hd95_metric: 0.2192 - val_loss: 0.0096 - val_accuracy: 0.9963 - val_mean_io_u: 0.8886 - val_dice_coef: 0.7661 - val_precision: 0.9968 - val_sensitivity: 0.9959 - val_specificity: 0.9989 - val_hd95_metric: 0.2142
# Epoch 48/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0097 - accuracy: 0.9962 - mean_io_u: 0.8941 - dice_coef: 0.7607 - precision: 0.9967 - sensitivity: 0.9958 - specificity: 0.9989 - hd95_metric: 0.2225 - val_loss: 0.0097 - val_accuracy: 0.9962 - val_mean_io_u: 0.8943 - val_dice_coef: 0.7672 - val_precision: 0.9967 - val_sensitivity: 0.9958 - val_specificity: 0.9989 - val_hd95_metric: 0.2131
# Epoch 49/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0096 - accuracy: 0.9962 - mean_io_u: 0.8954 - dice_coef: 0.7632 - precision: 0.9967 - sensitivity: 0.9958 - specificity: 0.9989 - hd95_metric: 0.2174 - val_loss: 0.0096 - val_accuracy: 0.9963 - val_mean_io_u: 0.8751 - val_dice_coef: 0.7659 - val_precision: 0.9968 - val_sensitivity: 0.9959 - val_specificity: 0.9989 - val_hd95_metric: 0.2275
# Epoch 50/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0095 - accuracy: 0.9962 - mean_io_u: 0.8976 - dice_coef: 0.7645 - precision: 0.9967 - sensitivity: 0.9959 - specificity: 0.9989 - hd95_metric: 0.2108 - val_loss: 0.0096 - val_accuracy: 0.9963 - val_mean_io_u: 0.8978 - val_dice_coef: 0.7790 - val_precision: 0.9967 - val_sensitivity: 0.9960 - val_specificity: 0.9989 - val_hd95_metric: 0.1807
# Epoch 51/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0094 - accuracy: 0.9963 - mean_io_u: 0.8939 - dice_coef: 0.7655 - precision: 0.9967 - sensitivity: 0.9959 - specificity: 0.9989 - hd95_metric: 0.2084 - val_loss: 0.0096 - val_accuracy: 0.9963 - val_mean_io_u: 0.9275 - val_dice_coef: 0.7775 - val_precision: 0.9967 - val_sensitivity: 0.9960 - val_specificity: 0.9989 - val_hd95_metric: 0.2094
# Epoch 52/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0094 - accuracy: 0.9963 - mean_io_u: 0.8973 - dice_coef: 0.7667 - precision: 0.9967 - sensitivity: 0.9959 - specificity: 0.9989 - hd95_metric: 0.2090 - val_loss: 0.0097 - val_accuracy: 0.9963 - val_mean_io_u: 0.9178 - val_dice_coef: 0.7701 - val_precision: 0.9967 - val_sensitivity: 0.9959 - val_specificity: 0.9989 - val_hd95_metric: 0.2557
# Epoch 53/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0094 - accuracy: 0.9963 - mean_io_u: 0.8959 - dice_coef: 0.7677 - precision: 0.9967 - sensitivity: 0.9959 - specificity: 0.9989 - hd95_metric: 0.2047 - val_loss: 0.0096 - val_accuracy: 0.9963 - val_mean_io_u: 0.8992 - val_dice_coef: 0.7762 - val_precision: 0.9967 - val_sensitivity: 0.9960 - val_specificity: 0.9989 - val_hd95_metric: 0.2204
# Epoch 54/250
# 295/295 [==============================] - 243s 823ms/step - loss: 0.0093 - accuracy: 0.9963 - mean_io_u: 0.8964 - dice_coef: 0.7701 - precision: 0.9968 - sensitivity: 0.9960 - specificity: 0.9989 - hd95_metric: 0.2005 - val_loss: 0.0094 - val_accuracy: 0.9963 - val_mean_io_u: 0.8700 - val_dice_coef: 0.7677 - val_precision: 0.9968 - val_sensitivity: 0.9959 - val_specificity: 0.9989 - val_hd95_metric: 0.2317
# Epoch 55/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0093 - accuracy: 0.9963 - mean_io_u: 0.8982 - dice_coef: 0.7692 - precision: 0.9968 - sensitivity: 0.9959 - specificity: 0.9989 - hd95_metric: 0.2022 - val_loss: 0.0096 - val_accuracy: 0.9962 - val_mean_io_u: 0.8627 - val_dice_coef: 0.7742 - val_precision: 0.9967 - val_sensitivity: 0.9959 - val_specificity: 0.9989 - val_hd95_metric: 0.1970
# Epoch 56/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0092 - accuracy: 0.9964 - mean_io_u: 0.8992 - dice_coef: 0.7730 - precision: 0.9968 - sensitivity: 0.9960 - specificity: 0.9989 - hd95_metric: 0.1949 - val_loss: 0.0098 - val_accuracy: 0.9963 - val_mean_io_u: 0.8479 - val_dice_coef: 0.7764 - val_precision: 0.9967 - val_sensitivity: 0.9959 - val_specificity: 0.9989 - val_hd95_metric: 0.1672
# Epoch 57/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0092 - accuracy: 0.9964 - mean_io_u: 0.8998 - dice_coef: 0.7729 - precision: 0.9968 - sensitivity: 0.9960 - specificity: 0.9989 - hd95_metric: 0.1946 - val_loss: 0.0094 - val_accuracy: 0.9964 - val_mean_io_u: 0.8869 - val_dice_coef: 0.7801 - val_precision: 0.9968 - val_sensitivity: 0.9961 - val_specificity: 0.9989 - val_hd95_metric: 0.1939
# Epoch 58/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0091 - accuracy: 0.9964 - mean_io_u: 0.9003 - dice_coef: 0.7730 - precision: 0.9968 - sensitivity: 0.9960 - specificity: 0.9989 - hd95_metric: 0.1906 - val_loss: 0.0093 - val_accuracy: 0.9964 - val_mean_io_u: 0.8978 - val_dice_coef: 0.7808 - val_precision: 0.9968 - val_sensitivity: 0.9961 - val_specificity: 0.9989 - val_hd95_metric: 0.1991
# Epoch 59/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0092 - accuracy: 0.9963 - mean_io_u: 0.8993 - dice_coef: 0.7713 - precision: 0.9968 - sensitivity: 0.9960 - specificity: 0.9989 - hd95_metric: 0.1938 - val_loss: 0.0095 - val_accuracy: 0.9964 - val_mean_io_u: 0.9187 - val_dice_coef: 0.7820 - val_precision: 0.9967 - val_sensitivity: 0.9961 - val_specificity: 0.9989 - val_hd95_metric: 0.1994
# Epoch 60/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0091 - accuracy: 0.9964 - mean_io_u: 0.8965 - dice_coef: 0.7743 - precision: 0.9968 - sensitivity: 0.9960 - specificity: 0.9989 - hd95_metric: 0.1898 - val_loss: 0.0094 - val_accuracy: 0.9964 - val_mean_io_u: 0.9079 - val_dice_coef: 0.7823 - val_precision: 0.9968 - val_sensitivity: 0.9961 - val_specificity: 0.9989 - val_hd95_metric: 0.2106
# Epoch 61/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0091 - accuracy: 0.9964 - mean_io_u: 0.8983 - dice_coef: 0.7755 - precision: 0.9968 - sensitivity: 0.9961 - specificity: 0.9989 - hd95_metric: 0.1863 - val_loss: 0.0093 - val_accuracy: 0.9964 - val_mean_io_u: 0.9143 - val_dice_coef: 0.7800 - val_precision: 0.9968 - val_sensitivity: 0.9961 - val_specificity: 0.9989 - val_hd95_metric: 0.2025
# Epoch 62/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0090 - accuracy: 0.9964 - mean_io_u: 0.9001 - dice_coef: 0.7761 - precision: 0.9968 - sensitivity: 0.9961 - specificity: 0.9989 - hd95_metric: 0.1851 - val_loss: 0.0092 - val_accuracy: 0.9964 - val_mean_io_u: 0.9182 - val_dice_coef: 0.7791 - val_precision: 0.9968 - val_sensitivity: 0.9961 - val_specificity: 0.9989 - val_hd95_metric: 0.1938
# Epoch 63/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.
250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0085 - accuracy: 0.9966 - mean_io_u: 0.9057 - dice_coef: 0.7873 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1577 - val_loss: 0.0092 - val_accuracy: 0.9965 - val_mean_io_u: 0.8999 - val_dice_coef: 0.7905 - val_precision: 0.9969 - val_sensitivity: 0.9962 - val_specificity: 0.9990 - val_hd95_metric: 0.1809
# Epoch 79/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0087 - accuracy: 0.9965 - mean_io_u: 0.9014 - dice_coef: 0.7845 - precision: 0.9969 - sensitivity: 0.9962 - specificity: 0.9990 - hd95_metric: 0.1662 - val_loss: 0.0091 - val_accuracy: 0.9966 - val_mean_io_u: 0.9143 - val_dice_coef: 0.7962 - val_precision: 0.9969 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1388
# Epoch 80/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0086 - accuracy: 0.9966 - mean_io_u: 0.9047 - dice_coef: 0.7864 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1597 - val_loss: 0.0094 - val_accuracy: 0.9964 - val_mean_io_u: 0.8876 - val_dice_coef: 0.7922 - val_precision: 0.9968 - val_sensitivity: 0.9962 - val_specificity: 0.9989 - val_hd95_metric: 0.1455
# Epoch 81/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0085 - accuracy: 0.9966 - mean_io_u: 0.9039 - dice_coef: 0.7882 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1558 - val_loss: 0.0089 - val_accuracy: 0.9966 - val_mean_io_u: 0.9024 - val_dice_coef: 0.7914 - val_precision: 0.9969 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1502
# Epoch 82/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0085 - accuracy: 0.9966 - mean_io_u: 0.9060 - dice_coef: 0.7891 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1524 - val_loss: 0.0090 - val_accuracy: 0.9965 - val_mean_io_u: 0.9162 - val_dice_coef: 0.7930 - val_precision: 0.9969 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1548
# Epoch 83/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0086 - accuracy: 0.9966 - mean_io_u: 0.9039 - dice_coef: 0.7860 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1588 - val_loss: 0.0090 - val_accuracy: 0.9965 - val_mean_io_u: 0.9046 - val_dice_coef: 0.7876 - val_precision: 0.9969 - val_sensitivity: 0.9962 - val_specificity: 0.9990 - val_hd95_metric: 0.1698
# Epoch 84/250
# 295/295 [==============================] - 243s 823ms/step - loss: 0.0085 - accuracy: 0.9966 - mean_io_u: 0.9062 - dice_coef: 0.7890 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1531 - val_loss: 0.0090 - val_accuracy: 0.9966 - val_mean_io_u: 0.8920 - val_dice_coef: 0.7932 - val_precision: 0.9970 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1492
# Epoch 85/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.0085 - accuracy: 0.9966 - mean_io_u: 0.9069 - dice_coef: 0.7888 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1560 - val_loss: 0.0091 - val_accuracy: 0.9965 - val_mean_io_u: 0.9072 - val_dice_coef: 0.7962 - val_precision: 0.9968 - val_sensitivity: 0.9962 - val_specificity: 0.9989 - val_hd95_metric: 0.1242
# Epoch 86/250
# 295/295 [==============================] - 242s 822ms/step - loss: 0.
250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0084 - accuracy: 0.9967 - mean_io_u: 0.9069 - dice_coef: 0.7899 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - hd95_metric: 0.1480 - val_loss: 0.0089 - val_accuracy: 0.9966 - val_mean_io_u: 0.8901 - val_dice_coef: 0.7972 - val_precision: 0.9969 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1209
# Epoch 94/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0083 - accuracy: 0.9967 - mean_io_u: 0.9075 - dice_coef: 0.7941 - precision: 0.9971 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1417 - val_loss: 0.0090 - val_accuracy: 0.9966 - val_mean_io_u: 0.8962 - val_dice_coef: 0.7971 - val_precision: 0.9969 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1226
# Epoch 95/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0084 - accuracy: 0.9967 - mean_io_u: 0.9078 - dice_coef: 0.7917 - precision: 0.9970 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1467 - val_loss: 0.0087 - val_accuracy: 0.9967 - val_mean_io_u: 0.9103 - val_dice_coef: 0.7959 - val_precision: 0.9970 - val_sensitivity: 0.9964 - val_specificity: 0.9990 - val_hd95_metric: 0.1454
# Epoch 96/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0083 - accuracy: 0.9967 - mean_io_u: 0.9045 - dice_coef: 0.7933 - precision: 0.9971 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1406 - val_loss: 0.0088 - val_accuracy: 0.9967 - val_mean_io_u: 0.9092 - val_dice_coef: 0.7966 - val_precision: 0.9970 - val_sensitivity: 0.9964 - val_specificity: 0.9990 - val_hd95_metric: 0.1444
# Epoch 97/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0083 - accuracy: 0.9967 - mean_io_u: 0.9071 - dice_coef: 0.7934 - precision: 0.9971 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1401 - val_loss: 0.0087 - val_accuracy: 0.9967 - val_mean_io_u: 0.9067 - val_dice_coef: 0.7944 - val_precision: 0.9970 - val_sensitivity: 0.9964 - val_specificity: 0.9990 - val_hd95_metric: 0.1543
# Epoch 98/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0082 - accuracy: 0.9967 - mean_io_u: 0.9038 - dice_coef: 0.7946 - precision: 0.9971 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1376 - val_loss: 0.0090 - val_accuracy: 0.9966 - val_mean_io_u: 0.9182 - val_dice_coef: 0.7966 - val_precision: 0.9969 - val_sensitivity: 0.9964 - val_specificity: 0.9990 - val_hd95_metric: 0.1360
# Epoch 99/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0082 - accuracy: 0.9967 - mean_io_u: 0.9114 - dice_coef: 0.7943 - precision: 0.9971 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1392 - val_loss: 0.0089 - val_accuracy: 0.9967 - val_mean_io_u: 0.9190 - val_dice_coef: 0.8002 - val_precision: 0.9970 - val_sensitivity: 0.9964 - val_specificity: 0.9990 - val_hd95_metric: 0.1420
# Epoch 100/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.
250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0081 - accuracy: 0.9968 - mean_io_u: 0.9069 - dice_coef: 0.7975 - precision: 0.9971 - sensitivity: 0.9965 - specificity: 0.9990 - hd95_metric: 0.1321 - val_loss: 0.0089 - val_accuracy: 0.9966 - val_mean_io_u: 0.8427 - val_dice_coef: 0.7886 - val_precision: 0.9969 - val_sensitivity: 0.9963 - val_specificity: 0.9990 - val_hd95_metric: 0.1429
# Epoch 108/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0082 - accuracy: 0.9967 - mean_io_u: 0.9060 - dice_coef: 0.7953 - precision: 0.9971 - sensitivity: 0.9964 - specificity: 0.9990 - hd95_metric: 0.1377 - val_loss: 0.0085 - val_accuracy: 0.9967 - val_mean_io_u: 0.9286 - val_dice_coef: 0.8017 - val_precision: 0.9971 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1345
# Epoch 109/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0081 - accuracy: 0.9968 - mean_io_u: 0.9086 - dice_coef: 0.7981 - precision: 0.9971 - sensitivity: 0.9965 - specificity: 0.9990 - hd95_metric: 0.1305 - val_loss: 0.0086 - val_accuracy: 0.9967 - val_mean_io_u: 0.8871 - val_dice_coef: 0.7977 - val_precision: 0.9970 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1454
# Epoch 110/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0080 - accuracy: 0.9968 - mean_io_u: 0.9118 - dice_coef: 0.7992 - precision: 0.9971 - sensitivity: 0.9965 - specificity: 0.9990 - hd95_metric: 0.1298 - val_loss: 0.0086 - val_accuracy: 0.9968 - val_mean_io_u: 0.9016 - val_dice_coef: 0.8014 - val_precision: 0.9971 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1202
# Epoch 111/250
# 295/295 [==============================] - 243s 826ms/step - loss: 0.0082 - accuracy: 0.9968 - mean_io_u: 0.9086 - dice_coef: 0.7966 - precision: 0.9971 - sensitivity: 0.9965 - specificity: 0.9990 - hd95_metric: 0.1335 - val_loss: 0.0086 - val_accuracy: 0.9967 - val_mean_io_u: 0.8838 - val_dice_coef: 0.8014 - val_precision: 0.9971 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1250
# Epoch 112/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0080 - accuracy: 0.9968 - mean_io_u: 0.9115 - dice_coef: 0.7997 - precision: 0.9971 - sensitivity: 0.9965 - specificity: 0.9990 - hd95_metric: 0.1273 - val_loss: 0.0084 - val_accuracy: 0.9968 - val_mean_io_u: 0.9155 - val_dice_coef: 0.8042 - val_precision: 0.9971 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1348
# Epoch 113/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0079 - accuracy: 0.9968 - mean_io_u: 0.9131 - dice_coef: 0.8013 - precision: 0.9972 - sensitivity: 0.9966 - specificity: 0.9991 - hd95_metric: 0.1251 - val_loss: 0.0085 - val_accuracy: 0.9968 - val_mean_io_u: 0.9047 - val_dice_coef: 0.8063 - val_precision: 0.9971 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1122
# Epoch 114/250
# ...
# Epoch 214/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9217 - dice_coef: 0.8176 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0899 - val_loss: 0.0082 - val_accuracy: 0.9969 - val_mean_io_u: 0.9314 - val_dice_coef: 0.8155 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1020
# Epoch 215/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0073 - accuracy: 0.9971 - mean_io_u: 0.9219 - dice_coef: 0.8173 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0891 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_mean_io_u: 0.9362 - val_dice_coef: 0.8136 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1102
# Epoch 216/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9225 - dice_coef: 0.8181 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0888 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_mean_io_u: 0.9323 - val_dice_coef: 0.8077 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1183
# Epoch 217/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0073 - accuracy: 0.9971 - mean_io_u: 0.9229 - dice_coef: 0.8165 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0918 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_mean_io_u: 0.9113 - val_dice_coef: 0.8121 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1138
# Epoch 218/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9223 - dice_coef: 0.8185 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0899 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_mean_io_u: 0.9071 - val_dice_coef: 0.8178 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0834
# Epoch 219/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9234 - dice_coef: 0.8187 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0892 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_mean_io_u: 0.9161 - val_dice_coef: 0.8110 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1050
# Epoch 220/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9224 - dice_coef: 0.8186 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0892 - val_loss: 0.0082 - val_accuracy: 0.9969 - val_mean_io_u: 0.8875 - val_dice_coef: 0.8107 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0969
# Epoch 221/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9233 - dice_coef: 0.8184 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0891 - val_loss: 0.0081 - val_accuracy: 0.9970 - val_mean_io_u: 0.9250 - val_dice_coef: 0.8175 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0869
# Epoch 222/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0073 - accuracy: 0.9971 - mean_io_u: 0.9200 - dice_coef: 0.8157 - precision: 0.9973 - sensitivity: 0.9968 - specificity: 0.9991 - hd95_metric: 0.0926 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_mean_io_u: 0.9237 - val_dice_coef: 0.8099 - val_precision: 0.9972 - val_sensitivity: 0.9966 - val_specificity: 0.9991 - val_hd95_metric: 0.1233
# Epoch 223/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9204 - dice_coef: 0.8178 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0918 - val_loss: 0.0081 - val_accuracy: 0.9970 - val_mean_io_u: 0.9371 - val_dice_coef: 0.8143 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1231
# Epoch 224/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9228 - dice_coef: 0.8197 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0882 - val_loss: 0.0081 - val_accuracy: 0.9970 - val_mean_io_u: 0.9130 - val_dice_coef: 0.8172 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0919
# Epoch 225/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9971 - mean_io_u: 0.9250 - dice_coef: 0.8201 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0866 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_mean_io_u: 0.9307 - val_dice_coef: 0.8130 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1059
# Epoch 226/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9223 - dice_coef: 0.8183 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0885 - val_loss: 0.0085 - val_accuracy: 0.9968 - val_mean_io_u: 0.9125 - val_dice_coef: 0.7959 - val_precision: 0.9971 - val_sensitivity: 0.9965 - val_specificity: 0.9990 - val_hd95_metric: 0.1279
# Epoch 227/250
# 295/295 [==============================] - 243s 826ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9220 - dice_coef: 0.8191 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0896 - val_loss: 0.0082 - val_accuracy: 0.9969 - val_mean_io_u: 0.9300 - val_dice_coef: 0.8173 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0789
# Epoch 228/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0070 - accuracy: 0.9972 - mean_io_u: 0.9245 - dice_coef: 0.8232 - precision: 0.9974 - sensitivity: 0.9970 - specificity: 0.9991 - hd95_metric: 0.0801 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_mean_io_u: 0.9049 - val_dice_coef: 0.8121 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0948
# Epoch 229/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0070 - accuracy: 0.9972 - mean_io_u: 0.9248 - dice_coef: 0.8217 - precision: 0.9974 - sensitivity: 0.9970 - specificity: 0.9991 - hd95_metric: 0.0814 - val_loss: 0.0081 - val_accuracy: 0.9970 - val_mean_io_u: 0.9314 - val_dice_coef: 0.8132 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1026
# Epoch 230/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9971 - mean_io_u: 0.9252 - dice_coef: 0.8208 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0847 - val_loss: 0.0085 - val_accuracy: 0.9969 - val_mean_io_u: 0.9429 - val_dice_coef: 0.8166 - val_precision: 0.9971 - val_sensitivity: 0.9967 - val_specificity: 0.9990 - val_hd95_metric: 0.1048
# Epoch 231/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9972 - mean_io_u: 0.9271 - dice_coef: 0.8217 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0833 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9222 - val_dice_coef: 0.8197 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0880
# Epoch 232/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9251 - dice_coef: 0.8196 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0878 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_mean_io_u: 0.9357 - val_dice_coef: 0.8171 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.1004
# Epoch 233/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9230 - dice_coef: 0.8193 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0871 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9022 - val_dice_coef: 0.8152 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0969
# Epoch 234/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9971 - mean_io_u: 0.9229 - dice_coef: 0.8196 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0852 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_mean_io_u: 0.9168 - val_dice_coef: 0.8158 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0985
# Epoch 235/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0075 - accuracy: 0.9970 - mean_io_u: 0.9206 - dice_coef: 0.8128 - precision: 0.9973 - sensitivity: 0.9968 - specificity: 0.9991 - hd95_metric: 0.0979 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_mean_io_u: 0.8991 - val_dice_coef: 0.8145 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0870
# Epoch 236/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0074 - accuracy: 0.9971 - mean_io_u: 0.9225 - dice_coef: 0.8148 - precision: 0.9973 - sensitivity: 0.9968 - specificity: 0.9991 - hd95_metric: 0.0933 - val_loss: 0.0085 - val_accuracy: 0.9969 - val_mean_io_u: 0.9077 - val_dice_coef: 0.8150 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0932
# Epoch 237/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0073 - accuracy: 0.9971 - mean_io_u: 0.9229 - dice_coef: 0.8174 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0903 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9067 - val_dice_coef: 0.8169 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0933
# Epoch 238/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9971 - mean_io_u: 0.9226 - dice_coef: 0.8197 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0863 - val_loss: 0.0085 - val_accuracy: 0.9969 - val_mean_io_u: 0.8985 - val_dice_coef: 0.8107 - val_precision: 0.9971 - val_sensitivity: 0.9966 - val_specificity: 0.9990 - val_hd95_metric: 0.1070
# Epoch 239/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9972 - mean_io_u: 0.9251 - dice_coef: 0.8220 - precision: 0.9974 - sensitivity: 0.9970 - specificity: 0.9991 - hd95_metric: 0.0838 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_mean_io_u: 0.9228 - val_dice_coef: 0.8169 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.1004
# Epoch 240/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0070 - accuracy: 0.9972 - mean_io_u: 0.9254 - dice_coef: 0.8221 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0828 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_mean_io_u: 0.9330 - val_dice_coef: 0.8115 - val_precision: 0.9971 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.1051
# Epoch 241/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9207 - dice_coef: 0.8185 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0888 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_mean_io_u: 0.9205 - val_dice_coef: 0.8134 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0965
# Epoch 242/250
# 295/295 [==============================] - 243s 826ms/step - loss: 0.0071 - accuracy: 0.9972 - mean_io_u: 0.9237 - dice_coef: 0.8211 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0855 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9335 - val_dice_coef: 0.8167 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.1004
# Epoch 243/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9972 - mean_io_u: 0.9254 - dice_coef: 0.8222 - precision: 0.9974 - sensitivity: 0.9970 - specificity: 0.9991 - hd95_metric: 0.0832 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_mean_io_u: 0.9297 - val_dice_coef: 0.8149 - val_precision: 0.9972 - val_sensitivity: 0.9967 - val_specificity: 0.9991 - val_hd95_metric: 0.0938
# Epoch 244/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9971 - mean_io_u: 0.9239 - dice_coef: 0.8203 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0859 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9148 - val_dice_coef: 0.8155 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.1008
# Epoch 245/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0070 - accuracy: 0.9972 - mean_io_u: 0.9244 - dice_coef: 0.8226 - precision: 0.9974 - sensitivity: 0.9970 - specificity: 0.9991 - hd95_metric: 0.0820 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9100 - val_dice_coef: 0.8158 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0820
# Epoch 246/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9190 - dice_coef: 0.8200 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0861 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_mean_io_u: 0.9027 - val_dice_coef: 0.8142 - val_precision: 0.9971 - val_sensitivity: 0.9967 - val_specificity: 0.9990 - val_hd95_metric: 0.0837
# Epoch 247/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9971 - mean_io_u: 0.9245 - dice_coef: 0.8202 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0862 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9165 - val_dice_coef: 0.8188 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0955
# Epoch 248/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0070 - accuracy: 0.9972 - mean_io_u: 0.9245 - dice_coef: 0.8225 - precision: 0.9974 - sensitivity: 0.9970 - specificity: 0.9991 - hd95_metric: 0.0823 - val_loss: 0.0081 - val_accuracy: 0.9970 - val_mean_io_u: 0.9274 - val_dice_coef: 0.8138 - val_precision: 0.9973 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0996
# Epoch 249/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0071 - accuracy: 0.9972 - mean_io_u: 0.9204 - dice_coef: 0.8222 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0830 - val_loss: 0.0082 - val_accuracy: 0.9970 - val_mean_io_u: 0.9295 - val_dice_coef: 0.8151 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.1011
# Epoch 250/250
# 295/295 [==============================] - 243s 825ms/step - loss: 0.0072 - accuracy: 0.9971 - mean_io_u: 0.9233 - dice_coef: 0.8198 - precision: 0.9974 - sensitivity: 0.9969 - specificity: 0.9991 - hd95_metric: 0.0869 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_mean_io_u: 0.9350 - val_dice_coef: 0.8177 - val_precision: 0.9972 - val_sensitivity: 0.9968 - val_specificity: 0.9991 - val_hd95_metric: 0.0980
# Running time: 60743.73286604881 s

# %% [markdown]
# ## Penyimpanan Model dan Visualisasi

# %%
print("[INFO] saving brain tumor segmentation model...")
model.save(model_path, save_format="h5")  # Save dalam format .h5
print(model_path)

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

dice_coef = history.history['dice_coef']
val_dice_coef = history.history['val_dice_coef']
plt.plot(epochs, dice_coef, 'y', label='Training Dice Coef')
plt.plot(epochs, val_dice_coef, 'r', label='Validation Dice Coef')
plt.title('Training and validation Dice Coef')
plt.xlabel('Epochs')
plt.ylabel('Dice Coef')
plt.legend()
plt.show()

hd95_metric = history.history['hd95_metric']
val_hd95_metric = history.history['val_hd95_metric']
plt.plot(epochs, hd95_metric, 'y', label='Training HD95')
plt.plot(epochs, val_hd95_metric, 'r', label='Validation HD95')
plt.title('Training and validation HD95')
plt.xlabel('Epochs')
plt.ylabel('HD95')
plt.legend()
plt.show()
# Out:
# [INFO] saving brain tumor segmentation model...
# UNet_Tesis_Baru_112_250_128.model

# %% [markdown]
# ## Uji Coba dan Evaluasi Model

# %%
# Evaluasi model
print("[INFO] evaluating network...")
_, acc, mean_io_u, dice_coef, precision, sensitivity, specificity, hd95_metric = model.evaluate(val_dataset, 
                    batch_size=BS, steps=val_num_batches)

# Tampilkan hasil evaluasi model
print("Accuracy:", round(acc * 100.0), "%")
print("Mean IoU:", round(mean_io_u * 100.0), "%")
print("Dice Coefficient:", round(dice_coef * 100.0), "%")
print("Precision:", round(precision * 100.0), "%")
print("Sensitivity:", round(sensitivity * 100.0), "%")
print("Specificity:", round(specificity * 100.0), "%")
print("HD95:", (hd95_metric), "mm")
# Out:
# [INFO] evaluating network...
# 73/73 [==============================] - 43s 583ms/step - loss: 0.0083 - accuracy: 0.9970 - mean_io_u: 0.9350 - dice_coef: 0.8177 - precision: 0.9972 - sensitivity: 0.9968 - specificity: 0.9991 - hd95_metric: 0.0980
# Accuracy: 100 %
# Mean IoU: 94 %
# Dice Coefficient: 82 %
# Precision: 100 %
# Sensitivity: 100 %
# Specificity: 100 %
# HD95: 0.09801630675792694 mm
